# %% [markdown]
# # Tarea 4. Midiendo rendimiento y riesgo en un portafolio.
#
# <img style="float: right; margin: 0px 0px 15px 15px;" src="data:image/jpeg;base64,..." width="600px" height="400px" />
#
# **Resumen.**
# > En esta tarea, calcularás medidas de rendimiento esperado diario y volatilidad para cuatro diferentes portafolios. Usarás los históricos de precios que ya descargaste en la tarea anterior.
#
# **Criterio de revisión.**
# > Se te calificará de acuerdo a los resultados finales que reportes, basados en tu análisis.
#
# **Antes de comenzar.**
# > Por favor, copiar y pegar este archivo en otra ubicación. Antes de comenzar, nombrarlo *Tarea4_ApellidoNombre*, sin acentos y sin espacios; por ejemplo, en mi caso el archivo se llamaría *Tarea4_JimenezEsteban*. Resolver todos los puntos en dicho archivo y subir en este espacio.

# %% [markdown]
# ## 1. Descarga de datos (20 puntos)
#
# Descargar los precios diarios ajustados en el cierre para el índice S&P 500 (^GSPC), Microsoft (MSFT), Walgreens (WBA), y Tesla Motors (TSLA) durante el periodo comprendido del primero de enero del 2011 hasta el 31 de diciembre del 2015.
#
# 1. Mostrar el DataFrame de los precios diarios (5 puntos).
# 2. Graficar los precios (5 puntos).
# 3. Mostrar el DataFrame de los rendimientos porcentuales diarios (5 puntos).
# 4. Graficar los rendimientos (5 puntos).

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader.data as web

# %%
# Función para descargar precios de cierre ajustados de varios activos a la vez:
def get_closes(tickers, start_date=None, end_date=None, freq=None):
    # Fecha inicio por defecto (start_date='2011-01-01') y fecha fin por defecto (end_date='2015-12-31')
    # Frecuencia de muestreo por defecto (freq='d')
    # Creamos DataFrame vacío de precios, con el índice de las fechas
    closes = pd.DataFrame(columns = tickers, index=web.YahooDailyReader(symbols=tickers[0], start=start_date, end=end_date, interval=freq).read().index)
    # Agregamos cada uno de los precios con YahooDailyReader
    for ticker in tickers:
        df = web.YahooDailyReader(symbols=ticker, start=start_date, end=end_date, interval=freq).read()
        closes[ticker]=df['Adj Close']
    closes.index_name = 'Date'
    closes = closes.sort_index()
    return closes

# %%
# Información
names = ['^GSPC', 'MSFT', 'WBA', 'TSLA']
start, end = '2011-01-01', '2015-12-31'

# %%
daily_closes = get_closes(tickers=names, start_date=start, end_date=end, freq='d')
daily_closes
# Out:
#                   ^GSPC       MSFT        WBA        TSLA
# Date
# 2011-01-03  1271.869995  22.912699  33.120098   26.620001
# 2011-01-04  1270.199951  23.002779  33.398075   26.670000
# 2011-01-05  1276.560059  22.929071  33.861340   26.830000
# 2011-01-06  1273.849976  23.600565  33.962425   27.879999
# 2011-01-07  1271.500000  23.420408  33.760262   28.240000
# 2011-01-10  1269.750000  23.109228  34.493088   28.450001
# 2011-01-11  1274.479980  23.019156  34.392010   26.959999
# 2011-01-12  1285.959961  23.379471  34.703655   26.959999
# 2011-01-13  1283.760010  23.084660  35.074276   26.219999
# 2011-01-14  1293.239990  23.174734  34.905807   25.750000
# 2011-01-18  1295.020020  23.469542  35.352238   25.639999
# 2011-01-19  1281.920044  23.313950  34.771057   24.030001
# 2011-01-20  1280.260010  23.215685  35.049011   22.620001
# 2011-01-21  1283.349976  22.945452  35.116390   23.040001
# 2011-01-24  1290.839966  23.240253  34.947945   24.490000
# 2015-12-28 -0.002179  0.005030 -0.007171 -0.007026
# 2015-12-29  0.010630  0.010724  0.011417  0.035990
# 2015-12-30 -0.007217 -0.004244 -0.004953  0.003794
# 2015-12-31 -0.009412 -0.014740 -0.014238  0.008064
#
# [1257 rows x 4 columns]

# %%
plt.plot(daily_ret)
plt.show()

# %% [markdown]
# ## 2. Rendimiento esperado y volatilidad para cada activo (30 puntos)
#
# Usando los datos de rendimientos diarios de MSFT, WBA, y TSLA:
#
# 1. Reportar en un DataFrame el rendimiento esperado diario y la volatilidad diaria para cada activo. Reportar en otro DataFrame el rendimiento esperado anual y la volatilidad anual para cada activo (10 puntos).
# 2. Calcular la matriz de varianza-covarianza (base diaria) para los activos MSFT, WBA, y TSLA (10 puntos).
# 3. Calcular la matriz de correlación (base diaria) para los activos MSFT, WBA, y TSLA (10 puntos).

# %%
re=pd.DataFrame(daily_ret.mean(),columns=['RE'])
re
# Out:
#              RE
# ^GSPC  0.000425
# MSFT   0.000764
# WBA    0.000839
# TSLA   0.002296

# %%
# Volatilidad diaria (desviación estándar)
vd=pd.DataFrame(daily_ret.std(),columns=['VD'])
vd
# Out:
#              VD
# ^GSPC  0.009738
# MSFT   0.014799
# WBA    0.016246
# TSLA   0.033246

# %%
daily_ret_summary = pd.DataFrame(index=['Mean', 'Volatility'], columns=names)
daily_ret_summary.loc['Mean']=daily_ret.mean()
daily_ret_summary.loc['Volatility']=daily_ret.std()
daily_ret_summary
# Out:
#                   ^GSPC         MSFT         WBA        TSLA
# Mean        0.000424967  0.000763744  0.00083927  0.00229583
# Volatility   0.00973782    0.0147987   0.0162465   0.0332456

# %%
def calc_annual_ret(ret):
    
    return (1+ret).groupby(lambda date: date.year).prod()-1

# %%
ra=pd.DataFrame(calc_annual_ret(daily_ret))
ra
# Out:
#          ^GSPC      MSFT       WBA      TSLA
# 2011 -0.011220 -0.047546 -0.141398  0.072877
# 2012  0.134057  0.057989  0.152733  0.185924
# 2013  0.296012  0.442980  0.589405  3.441393
# 2014  0.113906  0.275646  0.359792  0.478495
# 2015 -0.007266  0.226919  0.136146  0.079133

# %%
# Resumen en base anual
annual_ret_summary = pd.DataFrame(index=['Mean', 'Volatility'], columns=names)
annual_ret_summary.loc['Mean']=daily_ret.mean()*252
annual_ret_summary.loc['Volatility']=daily_ret.std()*np.sqrt(252)
annual_ret_summary
# Out:
#                ^GSPC      MSFT       WBA      TSLA
# Mean        0.107092  0.192464  0.211496  0.578548
# Volatility  0.154583  0.234923  0.257905  0.527757

# %%
cov=daily_closes.cov()
cov
# Out:
#               ^GSPC         MSFT          WBA          TSLA
# ^GSPC  98635.708866  2580.995485  5716.229509  27963.740202
# MSFT    2580.995485    75.531603   152.895573    748.980293
# WBA     5716.229509   152.895573   371.916343   1653.612907
# TSLA   27963.740202   748.980293  1653.612907   8765.487245

# %%
corr= daily_closes.corr()
corr
# Out:
#           ^GSPC      MSFT       WBA      TSLA
# ^GSPC  1.000000  0.945596  0.943778  0.951021
# MSFT   0.945596  1.000000  0.912238  0.920488
# WBA    0.943778  0.912238  1.000000  0.915848
# TSLA   0.951021  0.920488  0.915848  1.000000

# %%
cov_d = daily_ret.cov()
cov_d = cov_d.iloc[1:4,1:4]

cov_d
# Out:
#           MSFT       WBA      TSLA
# MSFT  0.000219  0.000072  0.000120
# WBA   0.000072  0.000264  0.000083
# TSLA  0.000120  0.000083  0.001105

# %%
corr_d = daily_ret.corr()
corr_d = corr_d.iloc[1:4,1:4]

corr_d
# Out:
#           MSFT       WBA      TSLA
# MSFT  1.000000  0.298437  0.243817
# WBA   0.298437  1.000000  0.153495
# TSLA  0.243817  0.153495  1.000000

# %% [markdown]
# ## 3. Rentimiento esperado y volatilidad para portafolios (30 puntos)
#
# 1. Calcular los rendimientos diarios de los siguientes portafolios. Reportar en un DataFrame el rendimiento esperado anual y la volatilidad anual para cada portafolio, calculando lo anterior tratando cada portafolio como si fuera un activo individual (15 puntos).
#  - Portafolio 1: igualmente ponderado entre MSFT, WBA, y TSLA.
#  - Portafolio 2: 30% MSFT, 20% WBA, y 50% TSLA.
#  - Portafolio 3: 50% MSFT, 30% WBA, y 20% TSLA.
#  - Portafolio 4: 20% MSFT, 50% WBA, y 30% TSLA.
# 2. Para cada uno de los anteriores portafolios, reportar en otro DataFrame el rendimiento esperado anual y la volatilidad anual para cada portafolio, calculando lo anterior mediante las fórmulas de rendimiento esperado y volatilidad para portafolios derivadas en clase (10 puntos).
# 3. Comparar los resultados del punto uno con los del punto dos (5 puntos).

# %%
daily_ret['P1'] = 1/3*daily_ret.MSFT+1/3*daily_ret.WBA+1/3*daily_ret.TSLA
daily_ret['P2'] = 0.3*daily_ret.MSFT+0.2*daily_ret.WBA+0.5*daily_ret.TSLA
daily_ret['P3'] = 0.5*daily_ret.MSFT+0.3*daily_ret.WBA+0.2*daily_ret.TSLA
daily_ret['P4'] = 0.2*daily_ret.MSFT+0.5*daily_ret.WBA+0.3*daily_ret.TSLA

daily_ret
# Out:
#                ^GSPC      MSFT       WBA      TSLA        P1        P2  \
# Date
# 2011-01-04 -0.001313  0.003931  0.008393  0.001878  0.004734  0.003797
# 2011-01-05  0.005007 -0.003204  0.013871  0.005999  0.005555  0.004813
# 2011-01-06 -0.002123  0.029286  0.002985  0.039135  0.023802  0.028950
# 2011-01-07 -0.001845 -0.007634 -0.005953  0.012913 -0.000225  0.002976
# 2011-01-10 -0.001376 -0.013287  0.021707  0.007436  0.005285  0.004073
# 2011-01-11  0.003725 -0.003898 -0.002930 -0.052373 -0.019734 -0.027942
# 2011-01-12  0.009008  0.015653  0.009062  0.000000  0.008238  0.006508
# 2011-01-13 -0.001711 -0.012610  0.010680 -0.027448 -0.009793 -0.015371
# 2011-01-14  0.007385  0.003902 -0.004803 -0.017925 -0.006276 -0.008753
# 2011-01-18  0.001376  0.012721  0.012790 -0.004272  0.007080  0.004238
# 2011-01-19 -0.010116 -0.006630 -0.016440 -0.062792 -0.028621 -0.036673
# 2011-01-20 -0.001295 -0.004215  0.007994 -0.058677 -0.018299 -0.029004
# 2011-01-21  0.002414 -0.011640  0.001922  0.018568  0.002950  0.006176
# 2011-01-24  0.005836  0.012848 -0.004797  0.062934  0.023662  0.034362
# 2011-01-25  0.000263  0.002467 -0.006026  0.007758  0.001400  0.003414
# 2011-01-26  0.004221  0.011599  0.001213  0.002836  0.005216  0.005140
anual_ret_summ
# Out:
#          ^GSPC      MSFT       WBA      TSLA        P1        P2        P3  \
# Mean  0.107092  0.192464  0.211496  0.578548  0.327503  0.389312   0.27539
# Vol   0.154583  0.234923  0.257905  0.527757   0.24464  0.304428  0.211901
#
#             P4
# Mean  0.317805
# Vol   0.239615

# %%
WP1 = np.array([1/3,1/3,1/3])
WP2 = np.array([0.3,0.2,0.5])
WP3 = np.array([0.5,0.3,0.2])
WP4 = np.array([0.2,0.5,0.3])

WP = np.array([WP1, WP2, WP3, WP4]).T
WP
# Out:
# array([[0.33333333, 0.3       , 0.5       , 0.2       ],
#        [0.33333333, 0.2       , 0.3       , 0.5       ],
#        [0.33333333, 0.5       , 0.2       , 0.3       ]])

# %%
ErP1 = anual_ret_summ.iloc[:,1:4].loc['Mean'].dot(WP1)
ErP1
# Out:
# 0.32750258874714366

# %%
ErP2 = anual_ret_summ.iloc[:,1:4].loc['Mean'].dot(WP2)
ErP2
# Out:
# 0.38931237518650363

# %%
ErP3 = anual_ret_summ.iloc[:,1:4].loc['Mean'].dot(WP3)
ErP3
# Out:
# 0.27539022161672333

# %%
ErP4 = anual_ret_summ.iloc[:,1:4].loc['Mean'].dot(WP4)
ErP4
# Out:
# 0.317805169438204

# %%
std1 = np.sqrt(252*WP1.dot(cov_d).dot(WP1))
std1
# Out:
# 0.2446397225642194

# %%
std2 = np.sqrt(252*WP2.dot(cov_d).dot(WP2))
std2
# Out:
# 0.30442812676024084

# %%
std3 = np.sqrt(252*WP3.dot(cov_d).dot(WP3))
std3
# Out:
# 0.21190088114433506

# %%
std4 = np.sqrt(252*WP4.dot(cov_d).dot(WP4))
std4
# Out:
# 0.23961491629792409

# %% [markdown]
# ## 4. Gráfico de rendimientos esperados vs. volatilidad (20 puntos)
#
# Crear un gráfico de puntos que muestre el rendimiento esperado y la volatilidad para cada uno de los activos, el índice S&P500, y los cuatro portafolios en el espacio rendimiento esperado (eje y) contra volatilidad (eje x). Etiquetar cada uno de los puntos y los ejes apropiadamente.

# %%
import scipy.optimize as opt
import matplotlib.pyplot as plt

x = anual_ret_summ.loc['Vol'].values
y = anual_ret_summ.loc['Mean'].values
plt.figure(figsize=(8,6))
plt.title('RENDIMIENTO ESPERADO VS VOLATILIDAD',fontsize=14)
plt.xlabel('Volatilidad')
plt.ylabel('rendimiento esperado')
plt.plot(x,y,'ro',ms=10)

plt.text(x[0],y[0],anual_ret_summ.columns[0])
plt.text(x[1],y[1],anual_ret_summ.columns[1])
plt.text(x[2],y[2],anual_ret_summ.columns[2])
plt.text(x[3],y[3],anual_ret_summ.columns[3])
plt.text(x[4],y[4],anual_ret_summ.columns[4])
plt.text(x[5],y[5],anual_ret_summ.columns[5])
plt.text(x[6],y[6],anual_ret_summ.columns[6])
plt.text(x[7],y[7],anual_ret_summ.columns[7]);

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
